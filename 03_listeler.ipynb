# %%
my_list =[1,2,3]

# %%
my_list[0]
# Out:
# 1

# %%
my_list[0]=5

# %%
my_list
# Out:
# [5, 2, 3]

# %% [markdown]
# ## dizilerin içindekiler stringse değişim yapınca hata verir 'immutability' Ama sayıysa değiştirebiliyoruz

# %%
my_string="Yusuf"

# %%
my_string[0]
# Out:
# 'Y'

# %%
#my_string[0]=t

# %%
my_list.append(8)

# %%
my_list
# Out:
# [5, 2, 3, 8]

# %%
my_list.pop()
# Out:
# 8

# %%
my_list
# Out:
# [5, 2, 3]

# %%
my_mixed_list=[1,2,"A","B"]

# %%
my_mixed_list[0]
# Out:
# 1

# %%
my_mixed_list[-1]
# Out:
# 'B'

# %%
my_list_1=["a","b","c"]

# %%
my_list_2=["d","e","f"]

# %%
my_list_3=my_list_1+my_list_2

# %%
my_list_3
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
my_list_3=my_list_1*4

# %%
my_list_3
# Out:
# ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c']

# %%
my_list_1.reverse()

# %%
my_list_1
# Out:
# ['c', 'b', 'a']

# %% [markdown]
# #nested list

# %%
new_list=[1,4,"a"]

# %%
new_list=[1,4,"a",[3,"c"]]

# %%
new_list[2]
# Out:
# 'a'

# %%
new_list[3]
# Out:
# [3, 'c']

# %%
nested_list=new_list[3]

# %%
nested_list
# Out:
# [3, 'c']

# %%
nested_list[0]
# Out:
# 3

# %%
new_list[3][1]
# Out:
# 'c'

# %%
new_list
# Out:
# [1, 4, 'a', [3, 'c']]

# %%
new_list[2:]
# Out:
# ['a', [3, 'c']]

# %%
new_list[:2]
# Out:
# [1, 4]
