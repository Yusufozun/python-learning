# %%
if(3>2):
    print("3 is greater than 2")
# Out:
# 3 is greater than 2

# %%
x=3

# %%
y=4

# %%
if x>y:
    print("x is greater")
elif(x==y):
    print("x is y")
else:
    print("y is greater")
# Out:
# y is greater

# %%
my_superhero=input("superher0: ")

# %%
if my_superhero=="batman":
    print("batmaaaan")
elif my_superhero=="spiderman":
    print("spidermaaan")
elif my_superhero==("superman"):
    print("supermaaan")
else:
    print(":(")
# Out:
# :(

# %%
my_string="Hello world"

# %%
if "hello" in my_string:
    print("true")
else:
    print("false")
# Out:
# false

# %%
if "Hello" in my_string:
    print("true")
else:
    print("false")
# Out:
# true

# %%
my_list=[1,2,3,4,5]

# %%
if 2 in my_list:
    print("yes")
else:
    print("no")
# Out:
# yes

# %%
if 6 in my_list:
    print("yes")
else:
    print("no")
# Out:
# no

# %%
my_dictionary={"k1":100,"k2":200,"k3":300}

# %%
if 100 in my_dictionary.values():
    print("yesss")
else:
    print("no")
# Out:
# yesss
