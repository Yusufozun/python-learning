# %%
my_list=[1,2,3,1]

# %%
my_list
# Out:
# [1, 2, 3, 1]

# %% [markdown]
# ##castıng

# %%
my_set =set(my_list)

# %%
my_set
# Out:
# {1, 2, 3}

# %% [markdown]
# ##Aşağıdaki set 2 de eşitliği direkt set cinsinden yazdık süslü parantezle o yüzden direkt tekrarlayanları göstermedi

# %%
my_set_2={1,2,3,1}

# %%
my_set_2
# Out:
# {1, 2, 3}

# %%
type(my_set_2)
# Out:
# set

# %%
my_set_3 ={"a","b","a"}

# %%
my_set_3
# Out:
# {'a', 'b'}

# %%
my_list = []

# %%
type(my_list)
# Out:
# list

# %%
my_list
# Out:
# []

# %%
my_list.append(1)

# %%
my_list
# Out:
# [1]

# %%
my_set_4 ={}

# %%
my_set
# Out:
# {1, 2, 3}

# %%
type(my_set_4)
# Out:
# dict

# %%
my_set_4["key1"]=1

# %%
my_set_4
# Out:
# {'key1': 1}

# %%
my_set_5=set()

# %%
my_set_5
# Out:
# set()

# %%
my_set_5.add(1)

# %%
my_set_5.add(2)

# %%
my_set_5
# Out:
# {1, 2}

# %%
my_set_5.add(1)

# %%
my_set_5
# Out:
# {1, 2}
