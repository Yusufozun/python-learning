# %%
5+6
# Out:
# 11

# %%
900/6
# Out:
# 150.0

# %%
30*4
# Out:
# 120

# %%
2*2*2
# Out:
# 8

# %%
2**3
# Out:
# 8

# %%
2**9
# Out:
# 512

# %%
10%3
# Out:
# 1

# %% [markdown]
# VARİABLES

# %%
x=3

# %%
y=5

# %%
x+y
# Out:
# 8

# %%
x**y
# Out:
# 243

# %%
x=4

# %%
x+y
# Out:
# 9

# %%
r =input("r: ")

# %%
r=input("r: ")

# %%
r
# Out:
# '4'

# %%
type(r)
# Out:
# str

# %%
r_int=int(r)

# %%
type(r_int)
# Out:
# int

# %%
r_int*2*3.14
# Out:
# 25.12

# %%
x="hello world"

# %%
type(x)
# Out:
# str

# %% [markdown]
# Len(x):X değişkeninin uzunlugunu çıktı olarak verir

# %%
len(x)
# Out:
# 11

# %%
print("Hello \nPyhton")
# Out:
# Hello
# Pyhton

# %%
print("hello\tpyyhton")
# Out:
# hello	pyyhton

# %%
my_string="hello world"

# %%
my_string
# Out:
# 'hello world'

# %% [markdown]
# ##İndexing

# %%
my_string[0]
# Out:
# 'h'

# %%
my_string[4]
# Out:
# 'o'

# %%
my_string[-1]
# Out:
# 'd'

# %%
my_string_2="1234567890"

# %%
my_string_2[0]
# Out:
# '1'

# %% [markdown]
# ##slicing

# %%
my_string_2[2:]
# Out:
# '34567890'

# %% [markdown]
# ##stopping index

# %%
my_string_2[:4]
# Out:
# '1234'

# %%
my_string_2[5:8]
# Out:
# '678'

# %% [markdown]
# ##step size

# %%
my_string_2[::]
# Out:
# '1234567890'

# %%
my_string_2[::3]
# Out:
# '1470'

# %%
my_string_2[::-1]
# Out:
# '0987654321'

# %% [markdown]
# ##STRİNG METHODS

# %%
my_name="yusuf"

# %%
my_name.capitalize()
# Out:
# 'Yusuf'

# %%
my_name="Yusuf Özün"

# %%
my_name.split()
# Out:
# ['Yusuf', 'Özün']
