# %%
my_dictinary={"key":"value"}

# %%
my_dictinary["key"]
# Out:
# 'value'

# %% [markdown]
# ##Uzun yol

# %%
my_list=[100,200]

# %%
my_list_2= ["run","swim"]

# %%
my_list[0]
# Out:
# 100

# %% [markdown]
# ##Dictionary ile

# %%
my_fitness_dictionary = {"run":100,"swim":200}

# %%
my_fitness_dictionary["run"]
# Out:
# 100

# %%
my_fitness_dictionary["swim"]
# Out:
# 200

# %%
my_fitness_dictionary_2={"key1":1,"key2":2,"key3":"apple"}

# %%
my_fitness_dictionary_2["key1"]
# Out:
# 1

# %%
my_fitness_dictionary_2["key3"]
# Out:
# 'apple'

# %%
my_dictionary_3 ={"key1":10,20:30}

# %%
my_dictionary_3["key1"]
# Out:
# 10

# %%
my_dictionary_3[20]
# Out:
# 30

# %%
my_dictionary_4={"key1":100,"key2":[10,20,30],"key3":{"a":5}}

# %%
my_dictionary_4["key1"]
# Out:
# 100

# %%
my_dictionary_4["key2"]
# Out:
# [10, 20, 30]

# %%
my_dictionary_4["key3"]
# Out:
# {'a': 5}

# %%
my_dictionary_4.keys()
# Out:
# dict_keys(['key1', 'key2', 'key3'])

# %%
my_dictionary_4.values()
# Out:
# dict_values([100, [10, 20, 30], {'a': 5}])

# %%
my_dictionary_4["key3"]["a"]
# Out:
# 5

# %%
my_dictionary_5={"k1":1,"k2":2}

# %%
my_dictionary_5["k1"]=3

# %%
my_dictionary_5["k2"]
# Out:
# 2

# %%
my_dictionary_5
# Out:
# {'k1': 3, 'k2': 2}

# %%
my_dictionary_5["k3"]=7

# %%
my_dictionary_5
# Out:
# {'k1': 3, 'k2': 2, 'k3': 7}
